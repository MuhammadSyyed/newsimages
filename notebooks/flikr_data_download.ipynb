# %%
# !pip install kagglehub

# %%
import kagglehub
import shutil
cache_path = kagglehub.dataset_download(
    "hsankesara/flickr-image-dataset"
)

# %%
destination = "../dataset/flickr-image-dataset"
shutil.move(cache_path, destination)
print("Moved to:", destination)
